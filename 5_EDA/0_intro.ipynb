# %% [markdown]
# ## Understanding of Data

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('AB_NYC_2019(1).csv')
df
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48906 entries, 0 to 48905
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48906 non-null  int64
#  1   name                            48890 non-null  object
#  2   host_id                         48906 non-null  int64
#  3   host_name                       48885 non-null  object
#  4   neighbourhood_group             48906 non-null  object
#  5   neighbourhood                   48906 non-null  object
#  6   latitude                        48906 non-null  float64
#  7   longitude                       48906 non-null  float64
#  8   room_type                       48906 non-null  object
#  9   price                           48906 non-null  int64
#  10  minimum_nights                  48906 non-null  int64
#  11  number_of_reviews               48906 non-null  int64
# ...

# %% [markdown]
# Q1 Dimension of data?

# %%
df.shape
# Out:
# (48906, 16)

# %% [markdown]
# Q2 How does the data look like

# %%
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.sample(5)
# Out:
#              id                                       name   host_id  \
# 9071    6956358               Spacious & happy gem in LES!   7013442
# 36296  28885547                            GREENPOINT LOVE  58131408
# 15733  12723066                    NYC 2 BDRM Apt. Apt. 3A  17770287
# 13245   9988233               Cozy Two Room Studio Astoria    404692
# 16450  13203601  Sunny, cosmopolitan and modern apartment.  69286284
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9071     Rafael           Manhattan  Lower East Side  40.71996  -73.98729
# 36296     Dixie            Brooklyn       Greenpoint  40.73372  -73.94227
# 15733      Nina           Manhattan          Midtown  40.75030  -73.98144
# 13245    Romina              Queens          Astoria  40.76248  -73.91279
# 16450      Kofi           Manhattan      East Harlem  40.79566  -73.94137
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# Q3 What is the datatype of the column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48906 entries, 0 to 48905
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48906 non-null  int64
#  1   name                            48890 non-null  object
#  2   host_id                         48906 non-null  int64
#  3   host_name                       48885 non-null  object
#  4   neighbourhood_group             48906 non-null  object
#  5   neighbourhood                   48906 non-null  object
#  6   latitude                        48906 non-null  float64
#  7   longitude                       48906 non-null  float64
#  8   room_type                       48906 non-null  object
#  9   price                           48906 non-null  int64
#  10  minimum_nights                  48906 non-null  int64
#  11  number_of_reviews               48906 non-null  int64
# ...

# %% [markdown]
# Q4 Are there any missing values?

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Q5 How does a data look like mathematically?

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.890600e+04  4.890600e+04  48906.000000  48906.000000  48906.000000
# mean   1.901287e+07  6.760480e+07     40.728952    -73.952175    152.711324
# std    1.098557e+07  7.860866e+07      0.054529      0.046154    240.128713
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.464662e+06  7.809567e+06     40.690100    -73.983080     69.000000
# 50%    1.967545e+07  3.078463e+07     40.723080    -73.955685    106.000000
# 75%    2.915085e+07  1.074344e+08     40.763120    -73.936283    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48906.000000       48906.000000       38854.000000
# mean         7.031612          23.300454           1.373151
# std         20.512489          44.607175           1.680270
# ...

# %% [markdown]
# Q6 Are there any duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(11)

# %% [markdown]
# Q7 How many unique values in each column?

# %%
df.nunique()
# Out:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df['id'].unique().size
# Out:
# 48895

# %%
columns= df.columns
for col in columns:
    print("Column = ",col ,  '         unique values = ',df[col].unique().size)
    print("-"*30)
# Out:
# Column =  id          unique values =  48895
# ------------------------------
# Column =  name          unique values =  47897
# ------------------------------
# Column =  host_id          unique values =  37457
# ------------------------------
# Column =  host_name          unique values =  11453
# ------------------------------
# Column =  neighbourhood_group          unique values =  5
# ------------------------------
# Column =  neighbourhood          unique values =  221
# ------------------------------
# Column =  latitude          unique values =  19048
# ------------------------------
# Column =  longitude          unique values =  14718
# ------------------------------
# Column =  room_type          unique values =  3
# ------------------------------
# Column =  price          unique values =  674
# ------------------------------
# Column =  minimum_nights          unique values =  109
# ------------------------------
# ...

# %% [markdown]
# Q8 Are there any outlires in the numericsl columns?

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
print(sns.boxplot(df['id']))
print(sns.boxplot(df['host_id']))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
